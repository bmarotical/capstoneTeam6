# %% [markdown]
# ## Overview ##
#
# 1. 19 columns were identified as having NULL values, out of which 4 columns have more than 70 percent were NULL, which were dropped
# 2. The following attributes were chosen based on our initial correlation analysis; which are some of the common attributest between test datasets
#    LotArea , BldgType,  HouseStyle ,  YearBuilt,    FullBath,   HalfBath ,   BedroomAbvGr
# 3. Another correlation analysis was performed among the selected attributes to avoid multicollinearity
# 4. In order to avoid outliers, LotArea greater than 50,000 sq.ft. were eliminated
# 5. Test datasets are gathered from Delaware- Bear, Delaware- Newark, Delaware-Wilmington and the latest data from Iowa- Ames.
# 6. Full Bath, Half Bath, Year Built and lot area are the most significant predictors in the model
# 7. With this prediction model, predicted house price  is off by an average of  $53,600
# 8. The R^2 statistic shows how well the model explains SalePrice.
# 9. In this model, since R^2 and Adjusted R^2 are close, model is not overfit.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 

import seaborn as sns
from sklearn import metrics

import xgboost as xgb

import cpi
cpi.update()

# %% [markdown]
# ### Data Set

# %%
housingData=pd.read_csv('Data/housing.csv')
housingData.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# ## Basic EDA

# %%
housingData.shape
# Out:
# (1460, 81)

# %%
housingData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %% [markdown]
# ### Attribute Correlation Metrics

# %%
corr = housingData.corr()
corr.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col1 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col2 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col3 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col4 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col5 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col6 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col7 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col8 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col9 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col10 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col11 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col12 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col13 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col14 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col15 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col16 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col17 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col18 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col19 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col20 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col21 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col22 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col23 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col24 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col25 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col26 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col27 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col28 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col29 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col30 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col31 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col32 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col33 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col34 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col35 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col36 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row0_col37 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row1_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row1_col4 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row1_col5 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row1_col6 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row1_col7 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row1_col8 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row1_col9 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row1_col10 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row1_col11 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row1_col12 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row1_col13 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row1_col14 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row1_col15 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row1_col16 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row1_col17 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row1_col18 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row1_col19 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row1_col20 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_1b704351_e11f_11eb_834f_842afdc72ea8row1_col21 {
#             background-color:  #

# %% [markdown]
# ### Find missing Data

# %%
def find_missing_percent(data):
    """
    Returns dataframe containing the total missing values and percentage of total
    missing values of a column.
    """
    miss_df = pd.DataFrame({'ColumnName':[],'TotalMissingVals':[],'PercentMissing':[]})
    for col in data.columns:
        sum_miss_val = data[col].isnull().sum()
        percent_miss_val = round((sum_miss_val/data.shape[0])*100,2)
        miss_df = miss_df.append(dict(zip(miss_df.columns,[col,sum_miss_val,percent_miss_val])),ignore_index=True)
    return miss_df

# %%
miss_df = find_missing_percent(housingData)
'''Displays columns with missing values'''
display(miss_df[miss_df['PercentMissing']>0.0])
print("\n")

print("Number of columns with missing values:"+(str(miss_df[miss_df['PercentMissing']>0.0].shape[0])))
# Out:
#       ColumnName  TotalMissingVals  PercentMissing
# 3    LotFrontage             259.0           17.74
# 6          Alley            1369.0           93.77
# 25    MasVnrType               8.0            0.55
# 26    MasVnrArea               8.0            0.55
# 30      BsmtQual              37.0            2.53
# 31      BsmtCond              37.0            2.53
# 32  BsmtExposure              38.0            2.60
# 33  BsmtFinType1              37.0            2.53
# 35  BsmtFinType2              38.0            2.60
# 42    Electrical               1.0            0.07
# 57   FireplaceQu             690.0           47.26
# 58    GarageType              81.0            5.55
# 59   GarageYrBlt              81.0            5.55
# 60  GarageFinish              81.0            5.55
# 63    GarageQual              81.0            5.55
# 64    GarageCond              81.0            5.55
# 72        PoolQC            1453.0           99.52
# 73         Fence            1179.0           80.75
# 74   MiscFeature            1406.0           96.30
# Number of columns with missing values:19

# %%
drop_cols = miss_df[miss_df['PercentMissing'] >70.0].ColumnName.tolist()

print("Number of columns with more than 70%:"+ str(len(drop_cols)))
housingData = housingData.drop(drop_cols,axis=1)
#test = test.drop(drop_cols,axis =1)

miss_df = miss_df[miss_df['ColumnName'].isin(housingData.columns)]
'''Columns to Impute'''
impute_cols = miss_df[miss_df['TotalMissingVals']>0.0].ColumnName.tolist()
miss_df[miss_df['TotalMissingVals']>0.0]
# Out:
# Number of columns with more than 70%:4
#       ColumnName  TotalMissingVals  PercentMissing
# 3    LotFrontage             259.0           17.74
# 25    MasVnrType               8.0            0.55
# 26    MasVnrArea               8.0            0.55
# 30      BsmtQual              37.0            2.53
# 31      BsmtCond              37.0            2.53
# 32  BsmtExposure              38.0            2.60
# 33  BsmtFinType1              37.0            2.53
# 35  BsmtFinType2              38.0            2.60
# 42    Electrical               1.0            0.07
# 57   FireplaceQu             690.0           47.26
# 58    GarageType              81.0            5.55
# 59   GarageYrBlt              81.0            5.55
# 60  GarageFinish              81.0            5.55
# 63    GarageQual              81.0            5.55
# 64    GarageCond              81.0            5.55

# %% [markdown]
# ### Basic Stats

# %%
housingData.describe().transpose()
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# TotalBsmtSF    1460.0    1057.429452    438.705324      0.0     795.75
# 1stFlrSF       1460.0    1162.626712    386.587738    334.0     882.00
# 2ndFlrSF       1460.0     346.992466    436.528436      0.0       0.00
# LowQualFinSF   1460.0       5.844521     48.623081      0.0       0.00
# GrLivArea      1460.0    1515.463699    525.480383    334.0    1129.50
# BsmtFullBath   1460.0       0.425342      0.518911      0.0       0.00
# BsmtHalfBath   1460.0       0.057534      0.238753      0.0       0.00
# FullBath       1460.0       1.565068      0.550916      0.0       1.00
# HalfBath       1460.0       0.382877      0.502885      0.0       0.00
# BedroomAbvGr   1460.0       2.866438      0.815778      0.0       2.00
# KitchenAbvGr   1460.0       1.046575      0.220338      0.0       1.00
# TotRmsAbvGrd   1460.0       6.517808      1.625393      2.0       5.00
# Fireplaces     1460.0       0.613014      0.644666      0.0       0.00
# GarageYrBlt    1379.0    1978.506164     24.689725   1900.0    1961.00
# GarageCars     1460.0       1.767123      0.747315      0.0       1.00
# GarageArea     1460.0     472.980137    213.804841      0.0     334.50
# WoodDeckSF     1460.0      94.244521    125.338794      0.0       0.00
# OpenPorchSF    1460.0      46.660274     66.256028      0.0       0.00
# EnclosedPorch  1460.0      21.954110     61.119149      0.0       0.00
# 3SsnPorch      1460.0       3.409589     29.317331      0.0       0.00
# ScreenPorch    1460.0      15.060959     55.757415      0.0       0.00
# PoolArea       1460.0       2.758904     40.177307      0.0       0.00
# MiscVal        1460.0      43.489041    496.123024      0.0       0.00
# MoSold         1460.0       6.321918      2.703626      1.0       5.00
# YrSold         1460.0    2007.815753      1.328095   2006.0    2007.00
# SalePrice      1460.0  180921.195890  79442.502883  34900.0  129975.00
#
#                     50%        75%       max
# Id                730.5    1095.25    1460.0
# MSSubClass         50.0      70.00     190.0
# LotFrontage        69.0      80.00     313.0
# LotArea          9478.5   11601.50  215245.0
# OverallQual         6.0       7.00      10.0
# OverallCond         5.0       6.00       9.0
# YearBuilt        1973.0    2000.00    2010.0
# YearRemodAdd     1994.0    2004.00    2010.0
# MasVnrArea          0.0     166.00    1600.0
# BsmtFinSF1        383.5     712.25    5644.0
# BsmtFinSF2          0.0       0.00    1474.0
# BsmtUnfSF         477.5     808.00    2336.0
# TotalBsmtSF       991.5    1298.25    6110.0
# 1stFlrSF         1087.0    1391.25    4692.0
# 2ndFlrSF            0.0     728.00    2065.0
# LowQualFinSF        0.0       0.00     572.0
# GrLivArea        1464.0    1776.75    5642.0
# BsmtFullBath        0.0       1.00       3.0
# BsmtHalfBath        0.0       0.00       2.0
# FullBath            2.0       2.00       3.0
# HalfBath            0.0       1.00       2.0
# BedroomAbvGr        3.0       3.00       8.0
# KitchenAbvGr        1.0       1.00       3.0
# TotRmsAbvGrd        6.0       7.00      14.0
# Fireplaces          1.0       1.00       3.0
# GarageYrBlt      1980.0    2002.00    2010.0
# GarageCars          2.0       2.00       4.0
# GarageArea        480.0     576.00    1418.0
# WoodDeckSF          0.0     168.00     857.0
# OpenPorchSF        25.0      68.00     547.0
# EnclosedPorch       0.0       0.00     552.0
# 3SsnPorch           0.0       0.00     508.0
# ScreenPorch         0.0       0.00     480.0
# PoolArea            0.0       0.00     738.0
# MiscVal             0.0       0.00   15500.0
# MoSold              6.0       8.00      12.0
# YrSold           2008.0    2009.00    2010.0
# SalePrice      163000.0  214000.00  755000.0

# %%
freq1, bin_edges1=np.histogram(housingData.LotArea, bins='fd')

plt.figure(figsize=(15,5))  
ax1 = plt.subplot(1,2,1)
ax1.set_title('LotArea',fontsize=20)
ax1.set_xlabel('LotArea',fontsize=20)
ax1.set_ylabel('Frequency',fontsize=20)
housingData[['LotArea']].hist(bins=bin_edges1,ax = ax1, xlabelsize=10, ylabelsize=10)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001E86FE3CEE0>],
#       dtype=object)

# %% [markdown]
# ### Removing Outlier
#
# In order to avoid outliers, LotArea greater than 50,000 sq.ft. were eliminated

# %%
# Dropping lotArea greater than 50000 to remove outlier 
housingData = housingData[housingData.LotArea <= 50000].copy()
housingData.shape
# Out:
# (1449, 77)

# %% [markdown]
# ### Adjust for inflation using CPI

# %%
housingData['ADJUSTED_SalesPrice'] = housingData.apply(lambda x: cpi.inflate(x.SalePrice, x.YrSold), axis=1)

# %% [markdown]
# ##### Prepare the data by separating X and y
# ##### Dropping unimportant features, such as <>
# ##### Note that interesting features might be engieered from the dropped features above

# %%
X=housingData[['LotArea','BldgType','HouseStyle','YearBuilt','FullBath','HalfBath','BedroomAbvGr']].copy()
Y=housingData[['ADJUSTED_SalesPrice']]
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1449 entries, 0 to 1459
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LotArea       1449 non-null   int64
#  1   BldgType      1449 non-null   object
#  2   HouseStyle    1449 non-null   object
#  3   YearBuilt     1449 non-null   int64
#  4   FullBath      1449 non-null   int64
#  5   HalfBath      1449 non-null   int64
#  6   BedroomAbvGr  1449 non-null   int64
# dtypes: int64(5), object(2)
# memory usage: 90.6+ KB

# %%
X.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E80A4B2610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E80B7A9F10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E80A246190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E80C09F5E0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E80B640A30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E80BC6CEE0>]],
#       dtype=object)

# %%
Y.hist(figsize=(15,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E80BBC7E50>]],
#       dtype=object)

# %%
sns.pairplot(X[['LotArea', 'YearBuilt', 'FullBath', 'HalfBath',
       'BedroomAbvGr']], height=2)

# %% [markdown]
# ### Split the data into train and test

# %%
# Split the data into a training set and a test set. 
# Any number for the random_state is fine, see 42: https://en.wikipedia.org/wiki/42_(number) 
# We choose to use 20% (test_size=0.2) of the data set as the test set.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1159, 7)
# (290, 7)
# (1159, 1)
# (290, 1)

# %%
num_features =['LotArea', 'YearBuilt', 'FullBath', 'HalfBath','BedroomAbvGr']
cat_features = ['BldgType','HouseStyle']

# %% [markdown]
# ## Data pre-processing
# We will build a pipeline to do some of the following tasks:
#
# - Missing data
# - Feature scaling (important for certain model such as Gradient Descent based models)
# - Categorical feature encoding
# - Outlier removal
# - Transformation
# - Custom processing

# %%
# any missing values?
X_train.isnull().sum()
# Out:
# LotArea         0
# BldgType        0
# HouseStyle      0
# YearBuilt       0
# FullBath        0
# HalfBath        0
# BedroomAbvGr    0
# dtype: int64

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.preprocessing import PolynomialFeatures

# Create the preprocessing pipeline for numerical features
# Pipeline(steps=[(name1, transform1), (name2, transform2), ...]) 
# NOTE the step names can be arbitrary

# Step 1 is feature scaling via standardization - making features look like normal-distributed 
# see sandardization: https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html)
num_pipeline = Pipeline(
    steps=[
        #('poly',PolynomialFeatures(degree =2)),  # we will tune differet strategies later
        ('scaler', StandardScaler())
        ]
)

# Create the preprocessing pipelines for the categorical features
# There are two steps in this pipeline:
# Step 1: one hot encoding

cat_pipeline = Pipeline(
    steps=[
                ('onehot', OneHotEncoder())
    ]
)

# Assign features to the pipelines and Combine two pipelines to form the preprocessor
from sklearn.compose import ColumnTransformer

preprocessor = ColumnTransformer(
    transformers=[
        ('num_pipeline', num_pipeline, num_features),
        ('cat_pipeline', cat_pipeline, cat_features),
    ]
)

# %% [markdown]
# ## Model traning, tuning, evaluation and selection
#
# Next, we attach three different models (Linear, Ridge, XGBoost) to the same pre-processing pipeline and tune the some parameters using GridSearch with cross validation. Then, we compare their performance and choose the best model to proceed.

# %% [markdown]
# ### Using Linear Regression

# %%
# we show how to use GridSearch with K-fold cross validation (K=10) to fine tune the model
# we use the accuracy as the scoring metric with training score return_train_score=True
from sklearn.model_selection import GridSearchCV

# try Linear Regression
from sklearn.linear_model import LinearRegression

# rf pipeline
pipeline_lr = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', LinearRegression()),
])

parameters_lr=[
    {
        'classifier__fit_intercept': [True,False],
        'classifier__copy_X': [True, False],
        'classifier__normalize': [True, False]
    }
]                 

grid_search_lr = GridSearchCV(pipeline_lr,parameters_lr, cv=2)

# %%
grid_search_lr.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=2,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num_pipeline',
#                                                                          Pipeline(steps=[('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['LotArea',
#                                                                           'YearBuilt',
#                                                                           'FullBath',
#                                                                           'HalfBath',
#                                                                           'BedroomAbvGr']),
#                                                                         ('cat_pipeline',
#                                                                          Pipeline(steps=[('onehot',
#                                                                                           OneHotEncoder())]),
#                                                                          ['BldgType',
#                                                                           'HouseStyle'])])),
#                                        ('classifier', LinearRegression())]),
#              param_grid=[{'classifier__copy_X': [True, False],
#                           'classifier__fit_intercept': [True, False],
#                           'classifier__normalize': [True, False]}])

# %%
# check the best performing parameter combination
grid_search_lr.best_params_
# Out:
# {'classifier__copy_X': True,
#  'classifier__fit_intercept': True,
#  'classifier__normalize': False}

# %%
# build-in CV results keys
sorted(grid_search_lr.cv_results_.keys())
# Out:
# ['mean_fit_time',
#  'mean_score_time',
#  'mean_test_score',
#  'param_classifier__copy_X',
#  'param_classifier__fit_intercept',
#  'param_classifier__normalize',
#  'params',
#  'rank_test_score',
#  'split0_test_score',
#  'split1_test_score',
#  'std_fit_time',
#  'std_score_time',
#  'std_test_score']

# %%
# best linear regression model test score
grid_search_lr.best_score_
# Out:
# 0.5175904912577306

# %% [markdown]
# ### Using Ridge Classifier

# %%
from sklearn.linear_model import Ridge

# rf pipeline
pipeline_rg = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('clf_RG', Ridge()),
])

parameters_rg=[
    {
        'clf_RG__alpha': [0,0.2,0.01,1.0],
        'clf_RG__copy_X': [True, False],
        'clf_RG__fit_intercept': [True, False]
    }
]                 

grid_search_rg = GridSearchCV(pipeline_rg,parameters_rg, cv=5)

# %%
grid_search_rg.fit(X_train, y_train)
# Out:
# C:\Users\bhanu\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.03505e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\bhanu\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.54515e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\bhanu\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.32335e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\bhanu\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.03505e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\bhanu\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.54515e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\bhanu\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.32335e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num_pipeline',
#                                                                          Pipeline(steps=[('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['LotArea',
#                                                                           'YearBuilt',
#                                                                           'FullBath',
#                                                                           'HalfBath',
#                                                                           'BedroomAbvGr']),
#                                                                         ('cat_pipeline',
#                                                                          Pipeline(steps=[('onehot',
#                                                                                           OneHotEncoder())]),
#                                                                          ['BldgType',
#                                                                           'HouseStyle'])])),
#                                        ('clf_RG', Ridge())]),
#              param_grid=[{'clf_RG__alpha': [0, 0.2, 0.01, 1.0],
#                           'clf_RG__copy_X': [True, False],
#                           'clf_RG__fit_intercept': [True, False]}])

# %%
# best linear regression model test score
grid_search_rg.best_score_
# Out:
# 0.5198920543788462

# %% [markdown]
# ### Using XGBoost

# %%
# XGBoost pipeline
pipeline_xg = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('clf_XG', xgb.XGBRegressor()),
])

parameters_xg=[
    {
        'clf_XG__max_depth': [5,10,15,20,25,30],
        'clf_XG__learning_rate': [0.001,0.01,0.1,0.5],
        'clf_XG__n_estimators': [100,150,200,250,300]
        #'clf_XG__copy_X': [True, False],
        #'clf_XG__fit_intercept': [True, False]
    }
]                 

grid_search_xg = GridSearchCV(pipeline_xg,parameters_xg, cv=5)

# %%
grid_search_xg.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num_pipeline',
#                                                                          Pipeline(steps=[('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['LotArea',
#                                                                           'YearBuilt',
#                                                                           'FullBath',
#                                                                           'HalfBath',
#                                                                           'BedroomAbvGr']),
#                                                                         ('cat_pipeline',
#                                                                          Pipeline(steps=[('onehot',
#                                                                                           OneHotEncoder())]),
#                                                                          ['BldgType',
#                                                                           'HouseStyle'])])),
#                                        ('clf_XG',
#                                         XGBRegressor(base_score=None,
#                                                      boos...
#                                                      monotone_constraints=None,
#                                                      n_estimators=100,
#                                                      n_jobs=None,
#                                                      num_parallel_tree=None,
#                                                      random_state=None,
#                                                      reg_alpha=None,
#                                                      reg_lambda=None,
#                                                      scale_pos_weight=None,
#                                                      subsample=None,
#                                                      tree_method=None,
#                                                      validate_parameters=None,
#                                                      verbosity=None))]),
#              param_grid=[{'clf_XG__learning_rate': [0.001, 0.01, 0.1, 0.5],
#                           'clf_XG__max_depth': [5, 10, 15, 20, 25, 30],
#                           'clf_XG__n_estimators': [100, 150, 200, 250, 300]}])

# %%
grid_search_xg.best_score_
# Out:
# 0.6396406057404274

# %%
# best test score
print('best linear regression score is: ', grid_search_lr.best_score_)
print('best Ridge regression score is: ', grid_search_rg.best_score_)
print('best XGBoost  score is: ', grid_search_xg.best_score_)
# Out:
# best linear regression score is:  0.5175904912577306
# best Ridge regression score is:  0.5198920543788462
# best XGBoost  score is:  0.6396406057404274

# %%
# best parameters for all three are:
print('best parameter for linear regression are: ', grid_search_lr.best_params_)
print('best Ridge regression regression are: ', grid_search_rg.best_params_)
print('best XGBoost regression are: ', grid_search_xg.best_params_)
# Out:
# best parameter for linear regression are:  {'classifier__copy_X': True, 'classifier__fit_intercept': True, 'classifier__normalize': False}
# best Ridge regression regression are:  {'clf_RG__alpha': 0, 'clf_RG__copy_X': True, 'clf_RG__fit_intercept': True}
# best XGBoost regression are:  {'clf_XG__learning_rate': 0.1, 'clf_XG__max_depth': 5, 'clf_XG__n_estimators': 100}

# %%
# select the best model
# the best parameters are shown, note SimpleImputer() implies that mean strategry is used
clf_best = grid_search_lr.best_estimator_

# %%
from sklearn.metrics import accuracy_score

# %%
# final test on the testing set
# To predict on new data: simply calling the predict method 
# the full pipeline steps will be applied to the testing set followed by the prediction
y_pred = clf_best.predict(X_test)

# calculate accuracy, Note: y_test is the ground truth for the tesing set
# we have similiar score for the testing set as the cross validation score - good

#print('Accuracy Score :' (accuracy_score(y_test, y_pred)))

# %%
#===========   R-square and other metrics ===================
r_square= metrics.r2_score(y_test, y_pred)
mae_y = metrics.mean_absolute_error(y_test, y_pred)
mse_y = metrics.mean_squared_error(y_test, y_pred)
rmse_y = np.sqrt(metrics.mean_squared_error(y_test, y_pred))

print("Linear::r_square={0}::mean_absolute_error={1}::mean_square_error={2}::sqrt_mean_square_error={3}::".format(r_square,mae_y,mse_y,rmse_y))
# Out:
# Linear::r_square=0.5493236172117766::mean_absolute_error=41792.49293451337::mean_square_error=3497722942.8566914::sqrt_mean_square_error=59141.550054565625::

# %%
import xgboost

# %% [markdown]
# ## Feature Importance
#
# Given that we are using pipeline and one-hot encoding, the feature importance scores are not very straightforward to get. The following code shows how to get the feature importance scores from the Linear regression and create a plot.

# %%
clf_best.named_steps
# Out:
# {'preprocessor': ColumnTransformer(transformers=[('num_pipeline',
#                                   Pipeline(steps=[('scaler', StandardScaler())]),
#                                   ['LotArea', 'YearBuilt', 'FullBath',
#                                    'HalfBath', 'BedroomAbvGr']),
#                                  ('cat_pipeline',
#                                   Pipeline(steps=[('onehot', OneHotEncoder())]),
#                                   ['BldgType', 'HouseStyle'])]),
#  'classifier': LinearRegression()}

# %%
clf_best.named_steps['preprocessor']
# Out:
# ColumnTransformer(transformers=[('num_pipeline',
#                                  Pipeline(steps=[('scaler', StandardScaler())]),
#                                  ['LotArea', 'YearBuilt', 'FullBath',
#                                   'HalfBath', 'BedroomAbvGr']),
#                                 ('cat_pipeline',
#                                  Pipeline(steps=[('onehot', OneHotEncoder())]),
#                                  ['BldgType', 'HouseStyle'])])

# %%
i = clf_best.named_steps['classifier'].coef_
i
# Out:
# array([[ 20595.48593481,  27398.85099593,  28238.94921869,
#          11543.01133396,  -2754.22276202,  23702.98387695,
#           1464.84686376, -30410.53295122, -13098.94279403,
#          18341.64500454,   -628.74728834,    919.86789044,
#          -5251.19282405,  25814.33345982,  14759.49900329,
#          -6984.73730112,  -9378.18826902, -19250.83467102]])

# %%
clf_best['preprocessor'].transformers_
# Out:
# [('num_pipeline',
#   Pipeline(steps=[('scaler', StandardScaler())]),
#   ['LotArea', 'YearBuilt', 'FullBath', 'HalfBath', 'BedroomAbvGr']),
#  ('cat_pipeline',
#   Pipeline(steps=[('onehot', OneHotEncoder())]),
#   ['BldgType', 'HouseStyle'])]

# %%
# get columnTransformer
clf_best[0]
# Out:
# ColumnTransformer(transformers=[('num_pipeline',
#                                  Pipeline(steps=[('scaler', StandardScaler())]),
#                                  ['LotArea', 'YearBuilt', 'FullBath',
#                                   'HalfBath', 'BedroomAbvGr']),
#                                 ('cat_pipeline',
#                                  Pipeline(steps=[('onehot', OneHotEncoder())]),
#                                  ['BldgType', 'HouseStyle'])])

# %%
clf_best[0].transformers_
# Out:
# [('num_pipeline',
#   Pipeline(steps=[('scaler', StandardScaler())]),
#   ['LotArea', 'YearBuilt', 'FullBath', 'HalfBath', 'BedroomAbvGr']),
#  ('cat_pipeline',
#   Pipeline(steps=[('onehot', OneHotEncoder())]),
#   ['BldgType', 'HouseStyle'])]

# %%
num_original_feature_names = clf_best[0].transformers_[0][2]
num_original_feature_names
# Out:
# ['LotArea', 'YearBuilt', 'FullBath', 'HalfBath', 'BedroomAbvGr']

# %%
cat_original_feature_names = clf_best[0].transformers_[1][2]
cat_original_feature_names
# Out:
# ['BldgType', 'HouseStyle']

# %%
cat_new_feature_names = list(clf_best[0].transformers_[1][1]['onehot'].get_feature_names(cat_original_feature_names))
cat_new_feature_names
# Out:
# ['BldgType_1Fam',
#  'BldgType_2fmCon',
#  'BldgType_Duplex',
#  'BldgType_Twnhs',
#  'BldgType_TwnhsE',
#  'HouseStyle_1.5Fin',
#  'HouseStyle_1.5Unf',
#  'HouseStyle_1Story',
#  'HouseStyle_2.5Fin',
#  'HouseStyle_2.5Unf',
#  'HouseStyle_2Story',
#  'HouseStyle_SFoyer',
#  'HouseStyle_SLvl']

# %%
feature_names = num_original_feature_names + cat_new_feature_names
feature_names
# Out:
# ['LotArea',
#  'YearBuilt',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'BldgType_1Fam',
#  'BldgType_2fmCon',
#  'BldgType_Duplex',
#  'BldgType_Twnhs',
#  'BldgType_TwnhsE',
#  'HouseStyle_1.5Fin',
#  'HouseStyle_1.5Unf',
#  'HouseStyle_1Story',
#  'HouseStyle_2.5Fin',
#  'HouseStyle_2.5Unf',
#  'HouseStyle_2Story',
#  'HouseStyle_SFoyer',
#  'HouseStyle_SLvl']

# %%
r = pd.DataFrame(i, index=feature_names, columns=['importance'])
r
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\Softwares\anaconda3\envs\MISY631\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1661                 blocks = [
# -> 1662                     make_block(values=blocks[0], placement=slice(0, len(axes[0])))
#    1663                 ]
#
# D:\Softwares\anaconda3\envs\MISY631\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2721
# -> 2722     return klass(values, ndim=ndim, placement=placement)
#    2723
#
# D:\Softwares\anaconda3\envs\MISY631\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     130             raise ValueError(
# --> 131                 f"Wrong number of items passed {len(self.values)}, "
#     132                 f"placement implies {len(self.mgr_locs)}"
#
# ValueError: Wrong number of items passed 18, placement implies 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-ea18fb56b910> in <module>
# ----> 1 r = pd.DataFrame(i, index=feature_names, columns=['importance'])
#       2 r
#
# D:\Softwares\anaconda3\envs\MISY631\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     495                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     496             else:
# --> 497                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     498
#     499         # For data is list-like, or Iterable (will consume into list)
#
# D:\Softwares\anaconda3\envs\MISY631\lib\site-packages\pandas\core\internals\construction.py in init_ndarray(values, index, columns, dtype, copy)
#     232         block_values = [values]
#     233
# --> 234     return create_block_manager_from_blocks(block_values, [columns, index])
#     235
#     236
#
# D:\Softwares\anaconda3\envs\MISY631\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1670         blocks = [getattr(b, "values", b) for b in blocks]
#    1671         tot_items = sum(b.shape[0] for b in blocks)
# -> 1672         raise construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    1673
#    1674
#
# ValueError: Shape of passed values is (1, 18), indices imply (18, 1)

# %%
r.sort_values('importance', ascending=False)

# %%
r.sort_values('importance', ascending=False).plot.bar()

# %% [markdown]
# ## Remove unimportant Features

# %% [markdown]
# ## Persists the model

# %%
# Save the model as a pickle file
import joblib
joblib.dump(clf_best, "clf-best.pickle")
# Out:
# ['clf-best.pickle']

# %%
# Load the model from a pickle file
saved_linear_clf = joblib.load("clf-best.pickle")
saved_linear_clf
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num_pipeline',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['LotArea', 'YearBuilt',
#                                                    'FullBath', 'HalfBath',
#                                                    'BedroomAbvGr']),
#                                                  ('cat_pipeline',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder())]),
#                                                   ['BldgType',
#                                                    'HouseStyle'])])),
#                 ('classifier', LinearRegression())])

# %%
#Load Test Data
testhousingData=pd.read_csv('Data/test.csv')
testhousingData.head()

testhousingData.head()
testhousingData_df=testhousingData[['LotArea','BldgType','HouseStyle','YearBuilt','FullBath','HalfBath','BedroomAbvGr']].copy() #,'

# %%
pred1 = saved_linear_clf.predict(testhousingData_df)

# %%
pred1
# Out:
# array([[149124.96604395],
#        [177844.70760263],
#        [260836.05384084],
#        ...,
#        [178355.7849242 ],
#        [164435.24891678],
#        [238652.98620523]])

# %% [markdown]
# ## Test Datasets

# %%
newark_df=pd.read_csv('Data/Delaware - Newark.csv')
newark_df.head()
# Out:
#                                   primary_photo/href      last_update_date  \
# 0  https://ap.rdcpix.com/baddc47272800901657f4a06...  2021-06-25T11:29:53Z
# 1  https://ap.rdcpix.com/44d18cc63f349422e7936ad1...  2021-06-26T00:06:47Z
# 2  https://ap.rdcpix.com/c130c8a7a13ab8a7ed66bee6...  2021-06-25T16:13:49Z
# 3  https://ap.rdcpix.com/b53f18f0fa366b3cad7030f5...  2021-06-25T15:54:48Z
# 4  https://ap.rdcpix.com/0b1916875cead776686ee306...  2021-06-25T13:33:26Z
#
#   source/plan_id  source/agents/0/office_name  source/agents/1/office_name  \
# 0           None                         None                         None
# 1           None                         None                         None
# 2           None                         None  BHHS Fox & Roach-Greenville
# 3           None    Patterson-Schwartz-Newark                         None
# 4           None  RE/MAX Associates-Hockessin                         None
#
#   source/spec_id source/type       tags/0                   tags/1  \
# 0           None         mls  central_air           community_golf
# 1           None         mls  central_air  community_outdoor_space
# 2           None         mls  central_air  community_outdoor_space
# 3           None         mls  central_air      community_clubhouse
# 4           None         mls  central_air  community_outdoor_space
#
#                     tags/2  ... photos/3/tags/2/label  \
# 0  community_outdoor_space  ...                   NaN
# 1             laundry_room  ...                   NaN
# 2            den_or_office  ...                   NaN
# 3       community_elevator  ...                   NaN
# 4               cul_de_sac  ...                   NaN
#
#   photos/3/tags/2/probability photos/3/href photos/4/tags/0/label  \
# 0                         NaN           NaN                   NaN
# 1                         NaN           NaN                   NaN
# 2                         NaN           NaN                   NaN
# 3                         NaN           NaN                   NaN
# 4                         NaN           NaN                   NaN
#
#   photos/4/tags/0/probability photos/4/tags/1/label  \
# 0                         NaN                   NaN
# 1                         NaN                   NaN
# 2                         NaN                   NaN
# 3                         NaN                   NaN
# 4                         NaN                   NaN
#
#   photos/4/tags/1/probability photos/4/tags/2/label  \
# 0                         NaN                   NaN
# 1                         NaN                   NaN
# 2                         NaN                   NaN
# 3                         NaN                   NaN
# 4                         NaN                   NaN
#
#   photos/4/tags/2/probability photos/4/href
# 0                         NaN           NaN
# 1                         NaN           NaN
# 2                         NaN           NaN
# 3                         NaN           NaN
# 4                         NaN           NaN
#
# [5 rows x 163 columns]

# %%
bear_df=pd.read_csv('Data/Delaware - Bear.csv')
bear_df.head()
# Out:
#                                   primary_photo/href      last_update_date  \
# 0  https://ap.rdcpix.com/17d579e0422ad6eddad32cf8...  2021-06-26T00:07:05Z
# 1  https://ap.rdcpix.com/c5203540df21e416faf521fd...  2021-06-24T00:02:04Z
# 2  https://ap.rdcpix.com/40510892f3ac918357a54a33...  2021-06-21T12:52:11Z
# 3  https://ap.rdcpix.com/1309648972d5426a39b8b0b2...  2021-06-22T15:20:06Z
# 4  https://ap.rdcpix.com/455c360f8cdcc6eed32837ad...  2021-06-22T00:02:32Z
#
#    source/plan_id      source/agents/0/office_name  \
# 0             NaN                              NaN
# 1             NaN             Concord Realty Group
# 2             NaN     Patterson-Schwartz-Hockessin
# 3             NaN                              NaN
# 4             NaN  Long & Foster Real Estate, Inc.
#
#   source/agents/1/office_name  source/spec_id source/type       tags/0  \
# 0                         NaN             NaN         mls  central_air
# 1                         NaN             NaN         mls  central_air
# 2                         NaN             NaN         mls  central_air
# 3                         NaN             NaN         mls  central_air
# 4                         NaN             NaN         mls  central_air
#
#                     tags/1                   tags/2  ...  \
# 0  community_outdoor_space           community_park  ...
# 1  community_outdoor_space            den_or_office  ...
# 2      community_clubhouse  community_outdoor_space  ...
# 3  community_outdoor_space               cul_de_sac  ...
# 4  community_outdoor_space              dining_room  ...
#
#   photos/4/tags/2/label photos/4/tags/2/probability photos/4/href  \
# 0                   NaN                         NaN           NaN
# 1                   NaN                         NaN           NaN
# 2                   NaN                         NaN           NaN
# 3                   NaN                         NaN           NaN
# 4                   NaN                         NaN           NaN
#
#   photos/1/tags photos/2/tags photos/3/tags photos/4/tags photos/0/tags  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   location/address/coordinate location/county
# 0                         NaN             NaN
# 1                         NaN             NaN
# 2                         NaN             NaN
# 3                         NaN             NaN
# 4                         NaN             NaN
#
# [5 rows x 184 columns]

# %%
wilmigton_df=pd.read_csv('Data/Delaware - Wilmington.csv')
wilmigton_df.head()
# Out:
#                                   primary_photo/href      last_update_date  \
# 0  https://ap.rdcpix.com/23cc467793d4bfedb6feccb5...  2021-06-25T18:02:00Z
# 1  https://ap.rdcpix.com/c707363615d68117a8636f80...  2021-06-25T18:22:21Z
# 2  https://ap.rdcpix.com/ba0f521b142df98f24d612e5...  2021-06-25T14:30:15Z
# 3  https://ap.rdcpix.com/e826dda3d01f6475a845db79...  2021-06-26T00:04:32Z
# 4  https://ap.rdcpix.com/f424d73b1a395302dace4b9d...  2021-06-26T00:07:09Z
#
#    source/plan_id source/agents/0/office_name source/agents/1/office_name  \
# 0             NaN             EXP Realty, LLC                         NaN
# 1             NaN                         NaN                         NaN
# 2             NaN                         NaN                         NaN
# 3             NaN      Coldwell Banker Realty                         NaN
# 4             NaN                         NaN                         NaN
#
#    source/spec_id source/type       tags/0                   tags/1  \
# 0             NaN         mls  central_air  community_outdoor_space
# 1             NaN         mls  central_air  community_outdoor_space
# 2             NaN         mls   corner_lot    recreation_facilities
# 3             NaN         mls  central_air  community_outdoor_space
# 4             NaN         mls  central_air  community_outdoor_space
#
#                   tags/2  ... photos/0/tags tags/26 primary_photo photos  \
# 0          den_or_office  ...           NaN     NaN           NaN    NaN
# 1  recreation_facilities  ...           NaN     NaN           NaN    NaN
# 2               basement  ...           NaN     NaN           NaN    NaN
# 3             forced_air  ...           NaN     NaN           NaN    NaN
# 4             corner_lot  ...           NaN     NaN           NaN    NaN
#
#   tags/27 tags/28 tags/29 tags/30 tags/31  tags/32
# 0     NaN     NaN     NaN     NaN     NaN      NaN
# 1     NaN     NaN     NaN     NaN     NaN      NaN
# 2     NaN     NaN     NaN     NaN     NaN      NaN
# 3     NaN     NaN     NaN     NaN     NaN      NaN
# 4     NaN     NaN     NaN     NaN     NaN      NaN
#
# [5 rows x 146 columns]

# %%
ames_df=pd.read_csv('Data/IA - Ames.csv')
ames_df.head()
# Out:
#                                   primary_photo/href      last_update_date  \
# 0  https://ap.rdcpix.com/2e86200c4b34bb90707cffdd...  2021-06-25T13:32:56Z
# 1  https://ap.rdcpix.com/739ec9668785c076093ae3ff...  2021-06-23T15:51:31Z
# 2  https://ap.rdcpix.com/d1f50de0060b11c52eabdeef...  2021-06-25T13:09:27Z
# 3  https://ap.rdcpix.com/e99b2704465c3ef188bc34e6...  2021-06-21T14:39:48Z
# 4  https://ap.rdcpix.com/2af2e6ff416bd9137b3824bf...  2021-06-22T12:57:52Z
#
#    source/plan_id source/agents/0/office_name source/agents/1/office_name  \
# 0             NaN   CENTURY 21 SIGNATURE-Ames                         NaN
# 1             NaN                         NaN                         NaN
# 2             NaN      Hunziker & Assoc.-Ames      Hunziker & Assoc.-Ames
# 3             NaN                         NaN                         NaN
# 4             NaN                         NaN                         NaN
#
#    source/spec_id source/type       tags/0                   tags/1  \
# 0             NaN         mls  central_air  community_outdoor_space
# 1             NaN         mls  central_air  community_outdoor_space
# 2             NaN         mls  central_air  community_outdoor_space
# 3             NaN         mls  central_air  community_outdoor_space
# 4             NaN         mls  central_air  community_outdoor_space
#
#           tags/2  ... other_listings/rdc/14/listing_id  \
# 0  den_or_office  ...                              NaN
# 1     dishwasher  ...                              NaN
# 2     dishwasher  ...                              NaN
# 3     dishwasher  ...                              NaN
# 4     dishwasher  ...                              NaN
#
#   other_listings/rdc/14/listing_key other_listings/rdc/14/status  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
#
#   other_listings/rdc/14/primary other_listings/rdc/15/listing_id  \
# 0                           NaN                              NaN
# 1                           NaN                              NaN
# 2                           NaN                              NaN
# 3                           NaN                              NaN
# 4                           NaN                              NaN
#
#   other_listings/rdc/15/listing_key other_listings/rdc/15/status  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
#
#   other_listings/rdc/15/primary tags products
# 0                           NaN  NaN      NaN
# 1                           NaN  NaN      NaN
# 2                           NaN  NaN      NaN
# 3                           NaN  NaN      NaN
# 4                           NaN  NaN      NaN
#
# [5 rows x 200 columns]
